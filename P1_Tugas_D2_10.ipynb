# %% [markdown]
# <a href="https://colab.research.google.com/github/adamarsyadfaizin/PCVK26_10_Adam/blob/main/P1_Tugas_D2_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
urls = [
    "https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
    "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
    "https://iiif.lib.ncsu.edu/iiif/0016008/full/800,/0/default.jpg"
]

for url in urls:
    image = io.imread(url)
    image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
    image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
    final_frame = cv.hconcat((image, image_2))
    cv2_imshow(final_frame)
    print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x278>

# %%
for url in urls:
    image = io.imread(url)
    image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
    image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

    cv.line(image_2, (0, 0),
            (image_2.shape[1], image_2.shape[0]),
            (255, 255, 255), 1)
    cv.line(image_2, (image_2.shape[1], 0),
            (0, image_2.shape[0]),
            (255, 255, 255), 1)


    final_frame = cv.hconcat((image, image_2))
    cv2_imshow(final_frame)
    print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x278>

# %% [markdown]
# 1. Google Colab digunakan karena dapat menjalankan Python secara online tanpa perlu instalasi dan konfigurasi lingkungan Python secara manual
#
# 2. Kegunaan library:
# cv2 buat mengolah gambar
# numpy buat mengolah data/pixel dalam bentuk array
# skimage.io buat membaca gambar dari URL.
# cv2_imshow buat menampilkan gambar di Google Colab
#
# 3. digunakan untuk memperkecil ukuran gambar menjadi 50% dari ukuran awal namun Jika tidak dilakukan maka gambar tetap berukuran asli sehingga membutuhkan lebih banyak memori dan proses pengolahan dapat lebih berat jadinya
#
# 4. adalah nilai warna putih dalam format RGB aturannya yaitu R=255, G=255, B=255
#
# 5. Pixel adalah bagian terkecil penyusun gambar, jadi Semakin tinggi resolusi maka akan semakin banyak pixel sehingga gambar lebih detail dan tajam

# %%
y = image_2.shape[0] // 2
cv.line(
    image_2,
    (image_2.shape[1] // 2 - 50, y),
    (image_2.shape[1] // 2 + 50, y),
    (255, 255, 255),
    1
)
final_frame = cv.hconcat((image, image_2))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x278>

# %%
x1 = image_2.shape[1] // 2 - 40
y1 = image_2.shape[0] // 2 - 40
x2 = image_2.shape[1] // 2 + 40
y2 = image_2.shape[0] // 2 + 40

image_2[y1:y2, x1:x2] = [255, 255, 255]

final_frame = cv.hconcat((image, image_2))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x278>
